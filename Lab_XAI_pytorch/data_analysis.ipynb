# %% [markdown]
# # Exploratory Data Analysis

# %%
from utils.data_processing import *
from utils.utils_for_eda import *

X, y, feature_names = load_and_preprocess_data(dataset_path="../Data/MARSIS_historical_dataset.csv", orbit_path="../Data/orbit_to_remove", keep_flux=True)
# Out:
# Traceback (most recent call last):
#
#   File ~/projects/project_1/Lab_XAI/Lab_XAI_pytorch/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3748 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[4], line 2
#     from utils.utils_for_eda import *
#
#   File ~/projects/project_1/Lab_XAI/Lab_XAI_pytorch/utils/utils_for_eda.py:35
#     corr = np.corrcoef(y Harvey[:-lag], y[lag:])[0, 1]
#                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

#preparing data for EDA
df_eda = pd.DataFrame(X, columns=feature_names)
df_eda['TARGET_power'] = y

# %% [markdown]
# ## Analyzing target distribution

# %%
analyze_target_distribution(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 analyze_target_distribution(y)
#
# NameError: name 'analyze_target_distribution' is not defined
